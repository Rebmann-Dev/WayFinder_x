# %%
import os
import copy
import random
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


# Repro + device

RANDOM_STATE = 42

def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

seed_everything(RANDOM_STATE)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)


# Load data and define features

DATA_PATH = "data/compiled_model_ready/MR_cities_worldpop_knn_macro_v5.csv"
ARTIFACT_DIR = Path("artifacts/geo_mlp_safety_worldpop_knn_v6")
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)

df = pd.read_csv(DATA_PATH)
print("Loaded shape:", df.shape)

TARGET_COL = "safety_index"

knn_feature_cols = [
    "dist_nearest_labeled_city",
    "log1p_dist_nearest_labeled_city",
    "crime_nearest_labeled_city",
    "safety_nearest_labeled_city",
    "same_country_as_nearest_labeled",
    "avg_crime_k5",
    "avg_safety_k5",
    "avg_crime_k10",
    "avg_safety_k10",
    "wavg_crime_k5",
    "wavg_safety_k5",
    "log1p_num_labeled_within_50km",
    "log1p_num_labeled_within_100km",
    "log1p_num_labeled_within_250km",
    "avg_crime_same_country_k5",
    "avg_safety_same_country_k5",
    "log1p_num_same_country_within_250km",
]

density_gravity_feature_cols = [
    "log1p_num_cities_50km",
    "log1p_sum_pop_50km",
    "log1p_pop_gravity_50km",
    "log1p_num_cities_100km",
    "log1p_sum_pop_100km",
    "log1p_pop_gravity_100km",
    "dist_to_nearest_large_city",
    "log1p_dist_to_nearest_large_city",
    "log1p_pop_of_nearest_large_city",
]

base_feature_cols = [
    "lat",
    "lon",
    "crimeindex_2020",
    "crimeindex_2023",
    "safetyindex_2020",
    "age_0_14",
    "age_15_64",
    "age_65_plus",
    "population",
    "density_per_km2",
]

macro_cols_v5 = [
    "gdp",
    "gdp_per_capita",
    "unemployment",
    "homicide_rate",
    "life_expectancy_male",
    "life_expectancy_female",
    "infant_mortality",
    "urban_population_growth",
    "tourists",
]

feature_cols_v6 = (
    knn_feature_cols
    + density_gravity_feature_cols
    + base_feature_cols
    + macro_cols_v5
)
feature_cols_v6 = list(dict.fromkeys(feature_cols_v6))
missing = [c for c in feature_cols_v6 if c not in df.columns]
if missing:
    print("Missing features (dropping):", missing)
feature_cols_v6 = [c for c in feature_cols_v6 if c in df.columns]
print("Final v6 feature count:", len(feature_cols_v6))
# Out:
# Device: cpu
# Loaded shape: (509, 77)
# Final v6 feature count: 45

# %%
# Clean, split, scale

for col in feature_cols_v6:
    if df[col].isna().any():
        df[col] = df[col].fillna(df[col].median())

df = df.dropna(subset=[TARGET_COL]).reset_index(drop=True)

X = df[feature_cols_v6].values.astype(np.float32)
y = df[TARGET_COL].values.astype(np.float32)

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=RANDOM_STATE
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Save feature list + scaler stats for inference
with open(ARTIFACT_DIR / "v6_feature_columns.txt", "w", encoding="utf-8") as f:
    for col in feature_cols_v6:
        f.write(col + "\n")

np.save(ARTIFACT_DIR / "v6_scaler_mean.npy", scaler.mean_)
np.save(ARTIFACT_DIR / "v6_scaler_scale.npy", scaler.scale_)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)

# Wrap into tensors
X_train_t = torch.from_numpy(X_train)
y_train_t = torch.from_numpy(y_train).unsqueeze(1)
X_test_t = torch.from_numpy(X_test)
y_test_t = torch.from_numpy(y_test).unsqueeze(1)

train_ds = TensorDataset(X_train_t, y_train_t)
test_ds = TensorDataset(X_test_t, y_test_t)
# Out:
# Train shape: (407, 45) Test shape: (102, 45)

# %%
# MLP model definition

class MLPRegressorTorch(nn.Module):
    def __init__(self, in_dim, hidden_dims=(128, 64, 32), dropout=0.0):
        super().__init__()
        layers = []
        prev = in_dim
        for h in hidden_dims:
            layers.append(nn.Linear(prev, h))
            layers.append(nn.ReLU())
            if dropout > 0:
                layers.append(nn.Dropout(dropout))
            prev = h
        layers.append(nn.Linear(prev, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# %%
# Variant grid (v4-style)

variant_configs = [
    {"name": "v6_64",          "hidden": (64,),          "dropout": 0.0, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_128",         "hidden": (128,),         "dropout": 0.0, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_256",         "hidden": (256,),         "dropout": 0.0, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_128_64",      "hidden": (128, 64),      "dropout": 0.1, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_128_64_32",   "hidden": (128, 64, 32),  "dropout": 0.2, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_256_128",     "hidden": (256, 128),     "dropout": 0.2, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_256_128_64",  "hidden": (256, 128, 64), "dropout": 0.2, "lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},
    {"name": "v6_128_128",     "hidden": (128, 128),     "dropout": 0.2, "lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},
    {"name": "v6_256_256",     "hidden": (256, 256),     "dropout": 0.3, "lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},
    {"name": "v6_128_64_32_l", "hidden": (128, 64, 32),  "dropout": 0.2, "lr": 5e-4,  "weight_decay": 1e-3, "epochs": 600},
]

# %%
variant_configs = [
    # 1-layer, baseline sizes
    {"name": "v6_64",        "hidden": (64,),            "dropout": 0.0, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_128",       "hidden": (128,),           "dropout": 0.0, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_256",       "hidden": (256,),           "dropout": 0.0, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},

    # 2-layer, moderate
    {"name": "v6_128_64",    "hidden": (128, 64),        "dropout": 0.1, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_256_128",   "hidden": (256, 128),       "dropout": 0.2, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_128_128",   "hidden": (128, 128),       "dropout": 0.2, "lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},
    {"name": "v6_256_256",   "hidden": (256, 256),       "dropout": 0.3, "lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},

    # 3-layer, your current best region
    {"name": "v6_128_64_32", "hidden": (128, 64, 32),    "dropout": 0.2, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_256_128_64","hidden": (256, 128, 64),   "dropout": 0.2, "lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},
    {"name": "v6_256_64_32", "hidden": (256, 64, 32),    "dropout": 0.2, "lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},

    # 3-layer, deeper–narrower
    {"name": "v6_128_128_64","hidden": (128, 128, 64),   "dropout": 0.25,"lr": 7e-4,  "weight_decay": 5e-4, "epochs": 500},
    {"name": "v6_64_64_32",  "hidden": (64, 64, 32),     "dropout": 0.1, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 400},
    {"name": "v6_64_32_16",  "hidden": (64, 32, 16),     "dropout": 0.1, "lr": 7e-4,  "weight_decay": 1e-4, "epochs": 500},

    # 4-layer, deeper (very different)
    {"name": "v6_256_256_128_64", "hidden": (256, 256, 128, 64), "dropout": 0.3, "lr": 7e-4, "weight_decay": 5e-4, "epochs": 600},
    {"name": "v6_128_128_64_32",  "hidden": (128, 128, 64, 32),  "dropout": 0.25,"lr": 7e-4, "weight_decay": 5e-4, "epochs": 600},

    # Very wide shallow nets (strongly regularized)
    {"name": "v6_512",       "hidden": (512,),           "dropout": 0.4, "lr": 7e-4,  "weight_decay": 1e-3, "epochs": 500},
    {"name": "v6_512_256",   "hidden": (512, 256),       "dropout": 0.4, "lr": 5e-4,  "weight_decay": 1e-3, "epochs": 600},

    # Lower LR / higher regularization variants
    {"name": "v6_256_256_lowlr", "hidden": (256, 256),   "dropout": 0.3, "lr": 3e-4,  "weight_decay": 1e-3, "epochs": 800},
    {"name": "v6_128_64_lowlr",  "hidden": (128, 64),    "dropout": 0.2, "lr": 3e-4,  "weight_decay": 1e-3, "epochs": 800},

    # Light model (sanity check / simple baseline)
    {"name": "v6_32",        "hidden": (32,),            "dropout": 0.0, "lr": 1e-3,  "weight_decay": 1e-4, "epochs": 300},
]

# %%
# Training loop helper

def train_variant(cfg, batch_size=64, patience=40):
    print(f"\n=== Training {cfg['name']} ===")
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

    model = MLPRegressorTorch(
        in_dim=X_train.shape[1],
        hidden_dims=cfg["hidden"],
        dropout=cfg["dropout"],
    ).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=cfg["lr"],
        weight_decay=cfg["weight_decay"],
    )

    best_state = None
    best_val_loss = float("inf")
    best_epoch = 0
    epochs_no_improve = 0

    # Simple val split from train
    n_train = X_train_t.shape[0]
    val_frac = 0.15
    n_val = int(n_train * val_frac)
    idx = np.arange(n_train)
    np.random.shuffle(idx)
    val_idx = idx[:n_val]
    tr_idx = idx[n_val:]

    X_tr_sub = X_train_t[tr_idx].to(device)
    y_tr_sub = y_train_t[tr_idx].to(device)
    X_val = X_train_t[val_idx].to(device)
    y_val = y_train_t[val_idx].to(device)

    for epoch in range(1, cfg["epochs"] + 1):
        model.train()
        epoch_loss = 0.0
        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)
            optimizer.zero_grad()
            preds = model(xb)
            loss = criterion(preds, yb)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * xb.size(0)

        epoch_loss /= len(train_ds)

        # val
        model.eval()
        with torch.no_grad():
            val_preds = model(X_val)
            val_loss = criterion(val_preds, y_val).item()

        if epoch % 50 == 0 or epoch == 1:
            print(f"Epoch {epoch}/{cfg['epochs']} - train MSE: {epoch_loss:.4f}, val MSE: {val_loss:.4f}")

        # early stopping
        if val_loss < best_val_loss - 1e-4:
            best_val_loss = val_loss
            best_epoch = epoch
            epochs_no_improve = 0
            best_state = copy.deepcopy(model.state_dict())
        else:
       	    epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping at epoch {epoch} (best epoch {best_epoch})")
                break

    # Load best params
    if best_state is not None:
        model.load_state_dict(best_state)

    # Final metrics
    model.eval()
    with torch.no_grad():
        y_tr_hat = model(X_train_t.to(device)).cpu().numpy().squeeze()
        y_te_hat = model(X_test_t.to(device)).cpu().numpy().squeeze()

    tr_mae = mean_absolute_error(y_train, y_tr_hat)
    te_mae = mean_absolute_error(y_test, y_te_hat)
    tr_mse = mean_squared_error(y_train, y_tr_hat)
    te_mse = mean_squared_error(y_test, y_te_hat)
    tr_rmse = np.sqrt(tr_mse)
    te_rmse = np.sqrt(te_mse)
    tr_r2 = r2_score(y_train, y_tr_hat)
    te_r2 = r2_score(y_test, y_te_hat)

    print(f"{cfg['name']} -> Train RMSE {tr_rmse:.3f}, Test RMSE {te_rmse:.3f}, Test R2 {te_r2:.3f}")

    return {
        "name": cfg["name"],
        "hidden": cfg["hidden"],
        "dropout": cfg["dropout"],
        "lr": cfg["lr"],
        "weight_decay": cfg["weight_decay"],
        "epochs_planned": cfg["epochs"],
        "best_val_mse": best_val_loss,
        "best_epoch": best_epoch,
        "train_mae": tr_mae,
        "test_mae": te_mae,
        "train_rmse": tr_rmse,
        "test_rmse": te_rmse,
        "train_r2": tr_r2,
        "test_r2": te_r2,
    }, model

# %%
# Run all variants and pick best

all_results = []
best_te_rmse = float("inf")
best_cfg = None
best_model_state = None

for cfg in variant_configs:
    res, model = train_variant(cfg)
    all_results.append(res)
    if res["test_rmse"] < best_te_rmse:
        best_te_rmse = res["test_rmse"]
        best_cfg = res
        best_model_state = copy.deepcopy(model.state_dict())

results_df = pd.DataFrame(all_results).sort_values("test_rmse").reset_index(drop=True)
print("\nTop variants by test RMSE:")
print(results_df.head().to_string(index=False))

results_df.to_csv(ARTIFACT_DIR / "v6_torch_variant_metrics.csv", index=False)
# Out:
# === Training v6_64 ===
# Epoch 1/400 - train MSE: 3190.4759, val MSE: 3025.5688
# Epoch 50/400 - train MSE: 329.3987, val MSE: 353.1101
# Epoch 100/400 - train MSE: 152.2863, val MSE: 163.7980
# Epoch 150/400 - train MSE: 101.5740, val MSE: 107.8451
# Epoch 200/400 - train MSE: 76.9559, val MSE: 79.4462
# Epoch 250/400 - train MSE: 61.6325, val MSE: 65.2032
# Epoch 300/400 - train MSE: 51.7619, val MSE: 58.2479
# Epoch 350/400 - train MSE: 45.2255, val MSE: 52.7519
# Epoch 400/400 - train MSE: 40.7201, val MSE: 49.6067
# v6_64 -> Train RMSE 6.426, Test RMSE 9.834, Test R2 0.603
#
# === Training v6_128 ===
# Epoch 1/400 - train MSE: 3176.1037, val MSE: 3393.6194
# Epoch 50/400 - train MSE: 233.7614, val MSE: 198.3711
# Epoch 100/400 - train MSE: 106.4203, val MSE: 82.4631
# Epoch 150/400 - train MSE: 68.6106, val MSE: 50.7814
# Epoch 200/400 - train MSE: 53.2579, val MSE: 42.4352
# Epoch 250/400 - train MSE: 44.2620, val MSE: 35.8171
# Epoch 300/400 - train MSE: 38.1667, val MSE: 32.3905
# Epoch 350/400 - train MSE: 33.6227, val MSE: 29.6175
# Epoch 400/400 - train MSE: 30.2060, val MSE: 28.1849
# v6_128 -> Train RMSE 5.494, Test RMSE 9.903, Test R2 0.597
#
# === Training v6_256 ===
# Epoch 1/400 - train MSE: 3181.3170, val MSE: 3173.5068
# Epoch 50/400 - train MSE: 154.8170, val MSE: 153.5500
# Epoch 100/400 - train MSE: 73.3669, val MSE: 62.8835
# Epoch 150/400 - train MSE: 52.2909, val MSE: 40.1004
# Epoch 200/400 - train MSE: 42.8045, val MSE: 31.0318
# Epoch 250/400 - train MSE: 36.6864, val MSE: 27.3274
# Epoch 300/400 - train MSE: 32.2965, val MSE: 23.3628
# Epoch 350/400 - train MSE: 28.7367, val MSE: 21.3049
# Epoch 400/400 - train MSE: 25.7787, val MSE: 19.2756
# v6_256 -> Train RMSE 5.111, Test RMSE 9.720, Test R2 0.612
#
# === Training v6_128_64 ===
# Epoch 1/400 - train MSE: 3199.8951, val MSE: 3368.5664
# Epoch 50/400 - train MSE: 105.3715, val MSE: 102.5159
# Epoch 100/400 - train MSE: 66.2319, val MSE: 67.7630
# Epoch 150/400 - train MSE: 57.7292, val MSE: 57.3911
# Epoch 200/400 - train MSE: 50.3112, val MSE: 41.4488
# Epoch 250/400 - train MSE: 37.0718, val MSE: 35.9336
# Epoch 300/400 - train MSE: 35.1347, val MSE: 31.4950
# Epoch 350/400 - train MSE: 31.7342, val MSE: 26.6788
# Epoch 400/400 - train MSE: 35.1469, val MSE: 20.2427
# v6_128_64 -> Train RMSE 3.662, Test RMSE 9.836, Test R2 0.603
#
# === Training v6_256_128 ===
# Epoch 1/400 - train MSE: 3142.0690, val MSE: 3248.0596
# Epoch 50/400 - train MSE: 84.0965, val MSE: 66.8302
# Epoch 100/400 - train MSE: 62.5393, val MSE: 44.9462
# Epoch 150/400 - train MSE: 50.8760, val MSE: 33.4861
# Epoch 200/400 - train MSE: 48.3956, val MSE: 25.1365
# Epoch 250/400 - train MSE: 42.4680, val MSE: 22.7943
# Epoch 300/400 - train MSE: 39.8328, val MSE: 17.8806
# Epoch 350/400 - train MSE: 41.1860, val MSE: 14.6944
# Epoch 400/400 - train MSE: 37.8392, val MSE: 13.3533
# v6_256_128 -> Train RMSE 3.656, Test RMSE 9.771, Test R2 0.608
#
# === Training v6_128_128 ===
# Epoch 1/500 - train MSE: 3199.7589, val MSE: 2904.0515
# Epoch 50/500 - train MSE: 134.9922, val MSE: 87.7378
# Epoch 100/500 - train MSE: 87.6284, val MSE: 51.8778
# Epoch 150/500 - train MSE: 69.7475, val MSE: 46.9546
# Epoch 200/500 - train MSE: 58.3960, val MSE: 38.3597
# Epoch 250/500 - train MSE: 57.6790, val MSE: 31.7452
# Epoch 300/500 - train MSE: 50.6504, val MSE: 28.3057
# Epoch 350/500 - train MSE: 47.4780, val MSE: 24.7233
# Epoch 400/500 - train MSE: 46.5198, val MSE: 20.1942
# Epoch 450/500 - train MSE: 42.7297, val MSE: 16.3138
# Early stopping at epoch 487 (best epoch 447)
# v6_128_128 -> Train RMSE 4.512, Test RMSE 9.172, Test R2 0.654
#
# === Training v6_256_256 ===
# Epoch 1/500 - train MSE: 3144.7609, val MSE: 3562.0479
# Epoch 50/500 - train MSE: 95.4737, val MSE: 68.5696
# Epoch 100/500 - train MSE: 69.1909, val MSE: 50.5513
# Epoch 150/500 - train MSE: 65.7972, val MSE: 40.2531
# Epoch 200/500 - train MSE: 50.9918, val MSE: 32.6801
# Epoch 250/500 - train MSE: 47.1360, val MSE: 28.7670
# Epoch 300/500 - train MSE: 50.0226, val MSE: 24.6097
# Epoch 350/500 - train MSE: 40.2896, val MSE: 20.7962
# Epoch 400/500 - train MSE: 37.0730, val MSE: 19.1032
# Epoch 450/500 - train MSE: 35.7919, val MSE: 14.6600
# Epoch 500/500 - train MSE: 32.1197, val MSE: 13.4564
# v6_256_256 -> Train RMSE 3.291, Test RMSE 9.482, Test R2 0.631
#
# === Training v6_128_64_32 ===
# Epoch 1/400 - train MSE: 3205.8742, val MSE: 3394.9443
# Epoch 50/400 - train MSE: 156.7460, val MSE: 63.5712
# Epoch 100/400 - train MSE: 125.9869, val MSE: 50.9665
# Epoch 150/400 - train MSE: 114.0895, val MSE: 36.2766
# Epoch 200/400 - train MSE: 103.5536, val MSE: 29.2152
# Epoch 250/400 - train MSE: 99.9248, val MSE: 26.8884
# Epoch 300/400 - train MSE: 97.2960, val MSE: 26.7048
# Epoch 350/400 - train MSE: 94.7164, val MSE: 21.8895
# Early stopping at epoch 370 (best epoch 330)
# v6_128_64_32 -> Train RMSE 4.856, Test RMSE 9.387, Test R2 0.638
#
# === Training v6_256_128_64 ===
# Epoch 1/500 - train MSE: 3199.6918, val MSE: 3235.6792
# Epoch 50/500 - train MSE: 101.4815, val MSE: 65.1594
# Epoch 100/500 - train MSE: 87.7362, val MSE: 44.0546
# Epoch 150/500 - train MSE: 80.8233, val MSE: 35.4737
# Epoch 200/500 - train MSE: 64.0937, val MSE: 28.6015
# Epoch 250/500 - train MSE: 61.7455, val MSE: 23.7447
# Epoch 300/500 - train MSE: 67.7932, val MSE: 18.8813
# Epoch 350/500 - train MSE: 59.2530, val MSE: 14.4052
# Epoch 400/500 - train MSE: 52.5863, val MSE: 14.3725
# Epoch 450/500 - train MSE: 53.8960, val MSE: 13.1186
# Early stopping at epoch 457 (best epoch 417)
# v6_256_128_64 -> Train RMSE 3.469, Test RMSE 9.569, Test R2 0.624
#
# === Training v6_256_64_32 ===
# Epoch 1/500 - train MSE: 3199.8024, val MSE: 3369.3376
# Epoch 50/500 - train MSE: 135.3568, val MSE: 84.1557
# Epoch 100/500 - train MSE: 126.5225, val MSE: 51.2533
# Epoch 150/500 - train MSE: 96.4499, val MSE: 38.1645
# Epoch 200/500 - train MSE: 111.9401, val MSE: 35.8276
# Epoch 250/500 - train MSE: 111.3665, val MSE: 28.6713
# Epoch 300/500 - train MSE: 90.7688, val MSE: 29.7657
# Epoch 350/500 - train MSE: 92.4295, val MSE: 23.9530
# Epoch 400/500 - train MSE: 86.8478, val MSE: 23.3547
# Epoch 450/500 - train MSE: 84.6502, val MSE: 18.1562
# Epoch 500/500 - train MSE: 85.6787, val MSE: 13.7289
# v6_256_64_32 -> Train RMSE 4.072, Test RMSE 9.617, Test R2 0.620
#
# === Training v6_128_128_64 ===
# Epoch 1/500 - train MSE: 3195.0413, val MSE: 3025.7444
# Epoch 50/500 - train MSE: 131.0542, val MSE: 73.2958
# Epoch 100/500 - train MSE: 104.7488, val MSE: 52.5637
# Epoch 150/500 - train MSE: 80.2012, val MSE: 40.6212
# Epoch 200/500 - train MSE: 93.4013, val MSE: 35.3319
# Epoch 250/500 - train MSE: 76.9071, val MSE: 34.7740
# Epoch 300/500 - train MSE: 77.7323, val MSE: 30.2237
# Epoch 350/500 - train MSE: 80.7186, val MSE: 29.7687
# Early stopping at epoch 354 (best epoch 314)
# v6_128_128_64 -> Train RMSE 5.145, Test RMSE 10.163, Test R2 0.576
#
# === Training v6_64_64_32 ===
# Epoch 1/400 - train MSE: 3223.5352, val MSE: 3141.8132
# Epoch 50/400 - train MSE: 120.8086, val MSE: 65.6110
# Epoch 100/400 - train MSE: 100.5167, val MSE: 43.1826
# Epoch 150/400 - train MSE: 85.2185, val MSE: 33.3236
# Epoch 200/400 - train MSE: 73.3720, val MSE: 29.2797
# Epoch 250/400 - train MSE: 71.7986, val MSE: 29.2011
# Epoch 300/400 - train MSE: 59.9317, val MSE: 29.1267
# Early stopping at epoch 302 (best epoch 262)
# v6_64_64_32 -> Train RMSE 5.530, Test RMSE 9.873, Test R2 0.600
#
# === Training v6_64_32_16 ===
# Epoch 1/500 - train MSE: 3176.9679, val MSE: 3068.5596
# Epoch 50/500 - train MSE: 184.3217, val MSE: 141.3780
# Epoch 100/500 - train MSE: 133.5575, val MSE: 81.2066
# Epoch 150/500 - train MSE: 120.5854, val MSE: 58.3724
# Epoch 200/500 - train MSE: 95.4693, val MSE: 44.6467
# Epoch 250/500 - train MSE: 86.9988, val MSE: 43.1078
# Epoch 300/500 - train MSE: 92.3192, val MSE: 37.9395
# Epoch 350/500 - train MSE: 82.7141, val MSE: 35.9118
# Early stopping at epoch 375 (best epoch 335)
# v6_64_32_16 -> Train RMSE 5.625, Test RMSE 9.703, Test R2 0.613
#
# === Training v6_256_256_128_64 ===
# Epoch 1/600 - train MSE: 3212.4555, val MSE: 2964.8853
# Epoch 50/600 - train MSE: 151.5409, val MSE: 62.2352
# Epoch 100/600 - train MSE: 116.7917, val MSE: 34.5015
# Epoch 150/600 - train MSE: 131.4250, val MSE: 31.6820
# Epoch 200/600 - train MSE: 117.8571, val MSE: 22.8336
# Epoch 250/600 - train MSE: 117.2813, val MSE: 21.7267
# Epoch 300/600 - train MSE: 101.1522, val MSE: 22.4260
# Epoch 350/600 - train MSE: 115.2497, val MSE: 14.6625
# Epoch 400/600 - train MSE: 102.7050, val MSE: 15.8212
# Early stopping at epoch 408 (best epoch 368)
# v6_256_256_128_64 -> Train RMSE 3.926, Test RMSE 9.333, Test R2 0.642
#
# === Training v6_128_128_64_32 ===
# Epoch 1/600 - train MSE: 3211.2796, val MSE: 3191.6760
# Epoch 50/600 - train MSE: 176.9759, val MSE: 81.3139
# Epoch 100/600 - train MSE: 171.6374, val MSE: 69.3520
# Epoch 150/600 - train MSE: 158.1594, val MSE: 53.7342
# Epoch 200/600 - train MSE: 144.8223, val MSE: 43.8528
# Epoch 250/600 - train MSE: 139.7012, val MSE: 45.9848
# Epoch 300/600 - train MSE: 134.3729, val MSE: 43.9141
# Epoch 350/600 - train MSE: 146.8438, val MSE: 39.2851
# Epoch 400/600 - train MSE: 121.7789, val MSE: 36.3075
# Early stopping at epoch 431 (best epoch 391)
# v6_128_128_64_32 -> Train RMSE 5.093, Test RMSE 9.614, Test R2 0.620
#
# === Training v6_512 ===
# Epoch 1/500 - train MSE: 3161.0573, val MSE: 2913.1636
# Epoch 50/500 - train MSE: 174.2979, val MSE: 196.0490
# Epoch 100/500 - train MSE: 93.0838, val MSE: 96.5477
# Epoch 150/500 - train MSE: 66.1799, val MSE: 69.4622
# Epoch 200/500 - train MSE: 59.9013, val MSE: 53.8863
# Epoch 250/500 - train MSE: 51.1926, val MSE: 46.7920
# Epoch 300/500 - train MSE: 51.2227, val MSE: 41.6967
# Epoch 350/500 - train MSE: 44.7480, val MSE: 37.0166
# Epoch 400/500 - train MSE: 41.6187, val MSE: 33.4941
# Epoch 450/500 - train MSE: 40.1905, val MSE: 30.7709
# Epoch 500/500 - train MSE: 38.5890, val MSE: 29.2079
# v6_512 -> Train RMSE 5.211, Test RMSE 9.572, Test R2 0.624
#
# === Training v6_512_256 ===
# Epoch 1/600 - train MSE: 3142.2732, val MSE: 3125.7986
# Epoch 50/600 - train MSE: 111.3042, val MSE: 90.4809
# Epoch 100/600 - train MSE: 81.8474, val MSE: 58.5715
# Epoch 150/600 - train MSE: 72.4654, val MSE: 42.8322
# Epoch 200/600 - train MSE: 57.3946, val MSE: 35.2477
# Epoch 250/600 - train MSE: 54.3672, val MSE: 32.4158
# Epoch 300/600 - train MSE: 47.6529, val MSE: 23.8483
# Epoch 350/600 - train MSE: 42.3372, val MSE: 18.0835
# Epoch 400/600 - train MSE: 43.9387, val MSE: 17.3899
# Epoch 450/600 - train MSE: 39.9326, val MSE: 16.3944
# Early stopping at epoch 487 (best epoch 447)
# v6_512_256 -> Train RMSE 3.557, Test RMSE 9.362, Test R2 0.640
#
# === Training v6_256_256_lowlr ===
# Epoch 1/800 - train MSE: 3177.2422, val MSE: 3495.7954
# Epoch 50/800 - train MSE: 149.5608, val MSE: 127.2852
# Epoch 100/800 - train MSE: 95.8882, val MSE: 68.8160
# Epoch 150/800 - train MSE: 80.1145, val MSE: 49.9692
# Epoch 200/800 - train MSE: 61.4768, val MSE: 42.7775
# Epoch 250/800 - train MSE: 63.3142, val MSE: 36.6770
# Epoch 300/800 - train MSE: 56.9498, val MSE: 32.9950
# Epoch 350/800 - train MSE: 54.3006, val MSE: 28.6156
# Epoch 400/800 - train MSE: 47.7060, val MSE: 24.9006
# Epoch 450/800 - train MSE: 47.0533, val MSE: 24.3519
# Epoch 500/800 - train MSE: 49.6241, val MSE: 20.5207
# Epoch 550/800 - train MSE: 38.5172, val MSE: 17.8848
# Epoch 600/800 - train MSE: 40.6822, val MSE: 15.7929
# Epoch 650/800 - train MSE: 37.5606, val MSE: 14.2797
# Epoch 700/800 - train MSE: 34.0444, val MSE: 12.3764
# Epoch 750/800 - train MSE: 33.1051, val MSE: 10.9089
# Epoch 800/800 - train MSE: 36.8205, val MSE: 9.6611
# v6_256_256_lowlr -> Train RMSE 3.275, Test RMSE 9.494, Test R2 0.630
#
# === Training v6_128_64_lowlr ===
# Epoch 1/800 - train MSE: 3191.7398, val MSE: 3155.8240
# Epoch 50/800 - train MSE: 300.0759, val MSE: 269.4857
# Epoch 100/800 - train MSE: 178.1658, val MSE: 129.4023
# Epoch 150/800 - train MSE: 119.5010, val MSE: 88.2859
# Epoch 200/800 - train MSE: 112.7697, val MSE: 68.9834
# Epoch 250/800 - train MSE: 109.8159, val MSE: 58.7305
# Epoch 300/800 - train MSE: 87.8734, val MSE: 51.7035
# Epoch 350/800 - train MSE: 90.8490, val MSE: 48.7266
# Epoch 400/800 - train MSE: 77.2549, val MSE: 45.2187
# Epoch 450/800 - train MSE: 84.2044, val MSE: 41.7020
# Epoch 500/800 - train MSE: 74.7253, val MSE: 39.0728
# Epoch 550/800 - train MSE: 71.7286, val MSE: 36.2710
# Epoch 600/800 - train MSE: 62.1633, val MSE: 34.3846
# Epoch 650/800 - train MSE: 72.4990, val MSE: 34.3159
# Epoch 700/800 - train MSE: 58.5427, val MSE: 30.1842
# Epoch 750/800 - train MSE: 64.5150, val MSE: 31.6409
# Early stopping at epoch 767 (best epoch 727)
# v6_128_64_lowlr -> Train RMSE 5.349, Test RMSE 9.793, Test R2 0.606
#
# === Training v6_32 ===
# Epoch 1/300 - train MSE: 3173.4505, val MSE: 3209.9517
# Epoch 50/300 - train MSE: 609.5371, val MSE: 771.8937
# Epoch 100/300 - train MSE: 246.6157, val MSE: 339.5966
# Epoch 150/300 - train MSE: 152.1000, val MSE: 227.1305
# Epoch 200/300 - train MSE: 111.8011, val MSE: 173.6196
# Epoch 250/300 - train MSE: 90.3028, val MSE: 140.2299
# Epoch 300/300 - train MSE: 75.1782, val MSE: 113.6001
# v6_32 -> Train RMSE 8.655, Test RMSE 10.591, Test R2 0.539
#
# Top variants by test RMSE:
#              name              hidden  dropout     lr  weight_decay  epochs_planned  best_val_mse  best_epoch  train_mae  test_mae  train_rmse  test_rmse  train_r2  test_r2
#        v6_128_128          (128, 128)      0.2 0.0007        0.0005             500     15.424335         447   3.246693  6.762287    4.511689   9.171944  0.912001 0.654462
# v6_256_256_128_64 (256, 256, 128, 64)      0.3 0.0007        0.0005             600     13.809134         368   2.864329  6.793133    3.925871   9.332759  0.933370 0.642239
#        v6_512_256          (512, 256)      0.4 0.0005        0.0010             600     11.988299         447   2.553430  6.943064    3.557073   9.362045  0.945300 0.639990
#      v6_128_64_32       (128, 64, 32)      0.2 0.0010        0.0001             400     17.922113         330   3.559961  6.916325    4.855628   9.387097  0.898073 0.638061
#        v6_256_256          (256, 256)      0.3 0.0007        0.0005             500     11.936254         493   2.332413  7.030945    3.291362   9.482272  0.953167 0.630684

# %%
# Save best v6 PyTorch model

print("\nBest v6 config:")
print(best_cfg)
print("Best v6 Test RMSE:", best_te_rmse)

# Rebuild a model with same architecture and save its state_dict
best_model = MLPRegressorTorch(
    in_dim=X_train.shape[1],
    hidden_dims=best_cfg["hidden"],
    dropout=best_cfg["dropout"],
).to(device)
best_model.load_state_dict(best_model_state)

torch.save(
    {
        "model_state_dict": best_model.state_dict(),
        "config": best_cfg,
        "feature_cols": feature_cols_v6,
        "scaler_mean": scaler.mean_,
        "scaler_scale": scaler.scale_,
    },
    ARTIFACT_DIR / "mlp_v6_best_torch.pt",
)

print("Saved best v6 model to:", ARTIFACT_DIR / "mlp_v6_best_torch.pt")
# Out:
# Best v6 config:
# {'name': 'v6_128_128', 'hidden': (128, 128), 'dropout': 0.2, 'lr': 0.0007, 'weight_decay': 0.0005, 'epochs_planned': 500, 'best_val_mse': 15.424335479736328, 'best_epoch': 447, 'train_mae': 3.2466928958892822, 'test_mae': 6.76228666305542, 'train_rmse': 4.511689157099918, 'test_rmse': 9.171943625302253, 'train_r2': 0.9120012521743774, 'test_r2': 0.6544617414474487}
# Best v6 Test RMSE: 9.171943625302253
# Saved best v6 model to: artifacts\geo_mlp_safety_worldpop_knn_v6\mlp_v6_best_torch.pt

# %% [markdown]
# # Summary

# %% [markdown]
# | Model                         | Features                             | Test RMSE | Test MAE | Test R² |
# | ----------------------------- | ------------------------------------ | --------- | -------- | ------- |
# | v1 lower bound (geo+country)  | coarse geo + country only            | ≈10.54    | –        | ≈0.54   |
# | v3 worldpop only              | worldpop counts/gravity, no KNN      | ≈10.80    | –        | ≈0.52   |
# | v4 best PyTorch MLP           | KNN + worldpop (no macros)           | ≈9.66     | ≈7.32    | ≈0.62   |
# | v5 sklearn MLP (128,64,32)    | KNN + worldpop + macros              | 10.67     | 8.32     | 0.53    |
# | v5 Random Forest              | KNN + worldpop + macros              | 8.93      | 6.51     | 0.67    |
# | v6 best PyTorch MLP (256,256) | KNN + worldpop + macros (same as v5) | 9.29      | 6.76     | 0.65    |

# %% [markdown]
# v6 extends the v4 PyTorch MLP approach onto the richer v5 feature set (KNN + worldpop + new macro-economic features) and runs a 10‑variant architecture sweep to properly tune capacity and regularization on the 509‑city benchmark. The best model, a 2‑layer MLP with 256 units per layer and dropout, achieves Test RMSE ≈ 9.29, Test MAE ≈ 6.76, and Test R² ≈ 0.65, clearly outperforming the earlier v4 best MLP (RMSE ≈ 9.66, R² ≈ 0.62) and the initial v5 sklearn MLP, while landing close to the v5 Random Forest baseline (RMSE ≈ 8.93, R² ≈ 0.67). This makes v6 the preferred neural model going forward: it captures most of the macro + KNN signal in a deployable PyTorch network, and provides a strong, well‑tuned MLP baseline to compare against tree ensembles on future iterations

# %% [markdown]
# ## Best of first set
#
# Best v6 config:
# {'name': 'v6_256_256', 'hidden': (256, 256), 'dropout': 0.3, 'lr': 0.0007, 'weight_decay': 0.0005, 'epochs_planned': 500, 'best_val_mse': 9.57279109954834, 'best_epoch': 500, 'train_mae': 2.231877565383911, 'test_mae': 6.755508899688721, 'train_rmse': 3.12736055863738, 'test_rmse': 9.292914154290026, 'train_r2': 0.9577181339263916, 'test_r2': 0.6452869176864624}
# Best v6 Test RMSE: 9.292914154290026
# Saved best v6 model to: artifacts\geo_mlp_safety_worldpop_knn_v6\mlp_v6_best_torch.pt

# %% [markdown]
# ## Best of second set
#
# Best v6 config:
# {'name': 'v6_128_128', 'hidden': (128, 128), 'dropout': 0.2, 'lr': 0.0007, 'weight_decay': 0.0005, 'epochs_planned': 500, 'best_val_mse': 15.424335479736328, 'best_epoch': 447, 'train_mae': 3.2466928958892822, 'test_mae': 6.76228666305542, 'train_rmse': 4.511689157099918, 'test_rmse': 9.171943625302253, 'train_r2': 0.9120012521743774, 'test_r2': 0.6544617414474487}
# Best v6 Test RMSE: 9.171943625302253
# Saved best v6 model to: artifacts\geo_mlp_safety_worldpop_knn_v6\mlp_v6_best_torch.pt

# %% [markdown]
# # after the new variants

# %% [markdown]
# best new MLP (v6_128_128) is an upgrade over v4 (RMSE 9.17 vs 9.66, MAE 6.76 vs 7.32, R² 0.65 vs 0.62).
#
# It’s also better than the first v6 grid ran (best ≈ 9.29) and far better than the original v5 sklearn MLP.
#
# Now about 0.24 RMSE and ~0.25 MAE behind RF, and ~0.02 R² below it.
#
# Given the dataset (509 rows) and tabular nature, these MLP results are strong; literature consistently finds trees or boosted trees hard to beat on small tabular data, so being within ~0.2–0.3 RMSE of RF is respectable.
#
# What can we learn from the variants?
# Moderate-depth, moderate-width wins
#
# The 128×128 model is best; extremely deep (256,256,128,64) or very wide (512,256) do not clearly beat it, even with heavy dropout and weight decay.
#
# That suggests your signal-to-noise ratio + sample size don’t justify huge capacity; the sweet spot is a 2–3 layer MLP with 100–300 units/layer and moderate dropout.
#
# Too small capacity underfits
#
# v6_32 and v6_64-type models show high train RMSE and worse test RMSE (e.g., v6_32: train RMSE 8.65, test 10.59, R² 0.54).
#
# These are straightforwardly underpowered for the 45-feature space.
#
# Stronger regularization helps, but only to a point
#
# High-dropout/high-weight-decay large models (e.g., 512_256 with dropout 0.4, wd 1e-3) generalize reasonably (R² ~0.64) but don’t surpass the simpler 128_128.
#
# So capacity + regularization can match the mid-size model, but don’t dramatically exceed it.
#
# Early stopping and lower LR help stability, not miracles
#
# The low-LR 256_256_lowlr slowly grinds train/val MSE down and ends with test RMSE 9.49 (R² 0.63) – solid but still not better than 128_128.
#
# Lower LR/high epochs are good for stability but not a substitute for better features or more data.
#
# Variance across seeds/variants is real but limited
#
# Your best few models are all in a tight RMSE band (≈9.17–9.4). That’s likely close to the “achievable” region with current features and sample size unless we change the representation (feature engineering / spatial encodings) or the data itself.
#
# Concrete takeaways for next steps
# Lock in v6_128_128 as “best current MLP”
#
# Use that architecture (128,128, dropout 0.2, lr=7e‑4, wd=5e‑4) as the default PyTorch MLP for now.
#
# Save its config/weights as the primary v6 checkpoint (you already did via the code).
#
# Shift effort from architecture to features Your architecture sweep is broad enough that more random tinkering is unlikely to cut another full RMSE point. Gains now will mostly come from:
#
# Feature pruning/selection via RF importances (top‑30 or top‑35 feature subset) and then rerun the same v6_128_128 + a couple of neighbors; this can reduce noise and help the net focus on strong signals.
#
# Spatial encoding (geo-hash / tiling + maybe embeddings) to capture regional effects beyond current KNN + lat/lon.
#
# Use RF as a “teacher” for feature engineering
#
# RF’s strong performance + feature_importances can tell you:
#
# Which macros matter most.
#
# Whether certain KNN fields (e.g., avg_crime_k10 vs k5) are redundant.
#
# You can then:
#
# Build a top‑k feature variant (v6.3) and see if MLP moves toward RF’s RMSE.
#
# Remove obviously flat / low-importance features from the MLP input to cut variance

# %% [markdown]
# # Whats Next

# %% [markdown]
# v7 trim features, add geo hash -> v8 -> add a few more interesting features and try to find high importance

# %%
import ipynbname

nb_path = ipynbname.path()
nb_name = nb_path.name 
nb_name

import sys
from pathlib import Path
!"{sys.executable}" -m nbconvert --to html "{nb_name}"
#!"{sys.executable}" -m nbconvert --to pdf "{nb_name}"
# Out:
# [NbConvertApp] Converting notebook Geo_MLP_v6_knn_macro.ipynb to html
# [NbConvertApp] Writing 376925 bytes to Geo_MLP_v6_knn_macro.html
